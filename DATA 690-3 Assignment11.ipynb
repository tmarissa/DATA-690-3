# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Create a list of Pandas Series
# "first_name": ["jane", "john", "jasmine", "teddy", "megan", "jeffrey", "edward", "jaime"]
# "last_name": ["olsen", "Totti", "kennedy", "roosevelt", "fox", "bridges", "scissorhand", "cox"]
# "age": [34, 28, 13, 45, 51, 36, 18, 65]

# %%
first_name = pd.Series(["jane", "john", "jasmine", "teddy", "megan", "jeffrey", "edward", "jaime"])
last_name = pd.Series(["olsen", "Totti", "kennedy", "roosevelt", "fox", "bridges", "scissorhand", "cox"])
age = pd.Series([34, 28, 13, 45, 51, 36, 18, 65])

# %% [markdown]
# Create a new DataFrame named customer using the above list of Pandas Series
# The column names will come from the keys above ("first_name", "last_name", "age).

# %%
customer = pd.DataFrame({"first name": first_name, "last name": last_name,
                         "age": age})
customer
# Out:
#   first name    last name  age
# 0       jane        olsen   34
# 1       john        Totti   28
# 2    jasmine      kennedy   13
# 3      teddy    roosevelt   45
# 4      megan          fox   51
# 5    jeffrey      bridges   36
# 6     edward  scissorhand   18
# 7      jaime          cox   65

# %% [markdown]
# Use the following selection and indexing techniques to create new DataFrames.
# - Using masking, select list of customers who are between 20 and 35 in age
# - Using slicing, selectg every other row.
# - Using fancy indexing, create a new DataFrame with only "last_name" and "age" columns

# %%
customer[(age>20) & (age<35)]
# Out:
#   first name last name  age
# 0       jane     olsen   34
# 1       john     Totti   28

# %%
customer[::2]
# Out:
#   first name    last name  age
# 0       jane        olsen   34
# 2    jasmine      kennedy   13
# 4      megan          fox   51
# 6     edward  scissorhand   18

# %%
customer[['last name', 'age']]
# Out:
#      last name  age
# 0        olsen   34
# 1        Totti   28
# 2      kennedy   13
# 3    roosevelt   45
# 4          fox   51
# 5      bridges   36
# 6  scissorhand   18
# 7          cox   65

# %% [markdown]
# Using implicit indexing attribute and slicing, create a new DataFrame with indices between 2 and 5.

# %%
customer[3:5]
# Out:
#   first name  last name  age
# 3      teddy  roosevelt   45
# 4      megan        fox   51

# %% [markdown]
# Create a new DataFrame named customer_amount_nan  by add another Pandas Series with following data (in addition to the list of series from above)
# "total_sales": [32.10, 50.80, 13.00, 98.21, NaN, 0.50, None, 77.01]

# %%
customer
# Out:
#   first name    last name  age
# 0       jane        olsen   34
# 1       john        Totti   28
# 2    jasmine      kennedy   13
# 3      teddy    roosevelt   45
# 4      megan          fox   51
# 5    jeffrey      bridges   36
# 6     edward  scissorhand   18
# 7      jaime          cox   65

# %%
NaN = np.nan
total_sales = pd.Series([32.10, 50.80, 13.00, 98.21, NaN, 0.50, None, 77.01])
total_sales = pd.Series(total_sales)

# %%
NaN = np.nan
total_sales = pd.Series([32.10, 50.80, 13.00, 98.21, NaN, 0.50, None, 77.01])
customer_amount_nan = pd.DataFrame({"first name": first_name, "last name": last_name,
                         "age": age, 'total sales': total_sales})
customer_amount_nan
# Out:
#   first name    last name  age  total sales
# 0       jane        olsen   34        32.10
# 1       john        Totti   28        50.80
# 2    jasmine      kennedy   13        13.00
# 3      teddy    roosevelt   45        98.21
# 4      megan          fox   51          NaN
# 5    jeffrey      bridges   36         0.50
# 6     edward  scissorhand   18          NaN
# 7      jaime          cox   65        77.01

# %% [markdown]
# Using forward fill, fill the missing values
# Using backward fill, fill the missing values
# Fill the missing values with value of 0.00

# %%
customer_amount_nan.fillna(method='ffill')
# Out:
#   first name    last name  age  total sales
# 0       jane        olsen   34        32.10
# 1       john        Totti   28        50.80
# 2    jasmine      kennedy   13        13.00
# 3      teddy    roosevelt   45        98.21
# 4      megan          fox   51        98.21
# 5    jeffrey      bridges   36         0.50
# 6     edward  scissorhand   18         0.50
# 7      jaime          cox   65        77.01

# %%
x = customer_amount_nan.fillna(method='bfill')

# %%
customer_amount_nan.fillna(0)
# Out:
#   first name    last name  age  total sales
# 0       jane        olsen   34        32.10
# 1       john        Totti   28        50.80
# 2    jasmine      kennedy   13        13.00
# 3      teddy    roosevelt   45        98.21
# 4      megan          fox   51         0.00
# 5    jeffrey      bridges   36         0.50
# 6     edward  scissorhand   18         0.00
# 7      jaime          cox   65        77.01
